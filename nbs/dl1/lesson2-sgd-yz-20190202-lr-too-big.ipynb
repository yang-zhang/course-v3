# %%
# %matplotlib inline
from fastai.basics import *

# %% [markdown]
# In this part of the lecture we explain Stochastic Gradient Descent (SGD) which is an **optimization** method commonly used in neural networks. We will illustrate the concepts with concrete examples.

# %% [markdown]
# #  Linear Regression problem

# %% [markdown]
# The goal of linear regression is to fit a line to a set of points.

# %%
n=100

# %%
x = torch.ones(n,2) 
x[:,0].uniform_(-1.,1)
x[:5]
# Out:
# tensor([[ 0.7169,  1.0000],
#         [ 0.8066,  1.0000],
#         [ 0.4961,  1.0000],
#         [-0.5354,  1.0000],
#         [ 0.0794,  1.0000]])

# %%
x.requires_grad
# Out:
# False

# %%
a = tensor(3.,2); a
# Out:
# tensor([3., 2.])

# %%
a.requires_grad
# Out:
# False

# %%
tensor
# Out:
# <function fastai.torch_core.tensor(x: Any, *rest) -> torch.Tensor>

# %%
Tensor
# Out:
# torch.Tensor

# %%
tensor(1, 2), Tensor(1, 2)
# Out:
# (tensor([1, 2]), tensor([[0., 0.]]))

# %%
y = x@a + torch.rand(n)

# %%
y.type()
# Out:
# 'torch.FloatTensor'

# %%
x.shape, a.shape, y.shape
# Out:
# (torch.Size([100, 2]), torch.Size([2]), torch.Size([100]))

# %%
plt.scatter(x[:,0], y);

# %% [markdown]
# You want to find **parameters** (weights) `a` such that you minimize the *error* between the points and the line `x@a`. Note that here `a` is unknown. For a regression problem the most common *error function* or *loss function* is the **mean squared error**.

# %%
def mse(y_hat, y): return ((y_hat-y)**2).mean()

# %% [markdown]
# Suppose we believe `a = (-1.0,1.0)` then we can compute `y_hat` which is our *prediction* and then compute our error.

# %%
a = tensor(-1.,1)

# %%
a.type()
# Out:
# 'torch.FloatTensor'

# %%
a.requires_grad
# Out:
# False

# %%
y_hat = x@a
mse(y_hat, y)
# Out:
# tensor(7.3640)

# %%
plt.scatter(x[:,0],y)
plt.scatter(x[:,0],y_hat);

# %% [markdown]
# So far we have specified the *model* (linear regression) and the *evaluation criteria* (or *loss function*). Now we need to handle *optimization*; that is, how do we find the best values for `a`? How do we find the best *fitting* linear regression.

# %% [markdown]
# # Gradient Descent

# %% [markdown]
# We would like to find the values of `a` that minimize `mse_loss`.
#
# **Gradient descent** is an algorithm that minimizes functions. Given a function defined by a set of parameters, gradient descent starts with an initial set of parameter values and iteratively moves toward a set of parameter values that minimize the function. This iterative minimization is achieved by taking steps in the negative direction of the function gradient.
#
# Here is gradient descent implemented in [PyTorch](http://pytorch.org/).

# %%
a = nn.Parameter(a); a
# Out:
# Parameter containing:
# tensor([-1.,  1.], requires_grad=True)

# %%
def update():
    y_hat = x@a
    loss = mse(y, y_hat)
    if t % 10 == 0: print(loss)
    loss.backward()
    with torch.no_grad():
        a.sub_(lr * a.grad)
        a.grad.zero_()

# %%
y_hat = x@a
loss = mse(y, y_hat)
loss.backward()

# %%
y.requires_grad, y.grad is None
# Out:
# (False, True)

# %%
a.grad
# Out:
# tensor([-2.5443, -2.8351])

# %%
lr = 1e0
for t in range(100): update()
# Out:
# tensor(7.3640, grad_fn=<MeanBackward1>)
# tensor(17.5652, grad_fn=<MeanBackward1>)
# tensor(18.1601, grad_fn=<MeanBackward1>)
# tensor(18.7753, grad_fn=<MeanBackward1>)
# tensor(19.4115, grad_fn=<MeanBackward1>)
# tensor(20.0692, grad_fn=<MeanBackward1>)
# tensor(20.7494, grad_fn=<MeanBackward1>)
# tensor(21.4527, grad_fn=<MeanBackward1>)
# tensor(22.1800, grad_fn=<MeanBackward1>)
# tensor(22.9321, grad_fn=<MeanBackward1>)

# %%
plt.scatter(x[:,0],y)
plt.scatter(x[:,0],x@a);

# %% [markdown]
# ## Animate it!

# %%
from matplotlib import animation, rc
rc('animation', html='jshtml')

# %%
a = nn.Parameter(tensor(-1.,1))

fig = plt.figure()
plt.scatter(x[:,0], y, c='orange')
line, = plt.plot(x[:,0], x@a)
plt.close()

def animate(i):
    update()
    line.set_ydata(x@a)
    return line,

animation.FuncAnimation(fig, animate, np.arange(0, 100), interval=20)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgf89a61d95908477fa034e08643120d75">
#     <br>
#     <input id="_anim_sliderf89a61d95908477fa034e08643120d75" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animf89a61d95908477fa034e08643120d75.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animf89a61d95908477fa034e08643120d75.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animf89a61d95908477fa034e08643120d75.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animf89a61d95908477fa034e08643120d75.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animf89a61d95908477fa034e08643120d75.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animf89a61d95908477fa034e08643120d75.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animf89a61d95908477fa034e08643120d75.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animf89a61d95908477fa034e08643120d75.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animf89a61d95908477fa034e08643120d75.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animf89a61d95908477fa034e08643120d75.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectf89a61d95908477fa034e08643120d75" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgf89a61d95908477fa034e08643120d75";
#     var slider_id = "_anim_sliderf89a61d95908477fa034e08643120d75";
#     var loop_select_id = "_anim_loop_selectf89a61d95908477fa034e08643120d75";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvOIA7rQAAIABJREFUeJzt3Xt0VOXdL/Dv5IaNoMglQoiShAAC\
# IdgyXHz1QEQjNy9Fo4JUUWhjXzyrqNWK8trKKRjaU6309fbO0lYOcrFWhbUIRQsop4dSYxR4QUUr\
# JggIEhIVFEImk+f8MWYymdl7Zu+ZfXv2/n7W6sI8c8lvDWm+PHv/nufxCSEEiIiIJJNhdwFERESp\
# YIAREZGUGGBERCQlBhgREUmJAUZERFJigBERkZQYYEREJCUGGBERSYkBRkREUmKAERGRlBhgREQk\
# JQYYERFJiQFGRERSYoAREZGUGGBERCQlBhgREUmJAUZERFJigBERkZQYYEREJCUGGBERSYkBRkRE\
# UmKAERGRlBhgREQkJQYYERFJiQFGRERSYoAREZGUGGBERCQlBhgREUmJAUZERFJigBERkZQYYERE\
# JCUGGBERSYkBRkREUmKAERGRlLLsLsAsffr0QWFhod1lEBFJpaGhAcePH7e7DE1cG2CFhYWoq6uz\
# uwwiIqn4/X67S9CMlxCJiEhKDDAiIpISA4yIiKTEACMiIikxwIiISEoMMCIip6tfBawrBFZnhP+s\
# X2V3RY7g2jZ6IiJXqF8F1FYBoVPhr08dCH8NAEWz7avLATgDIyJyst2LOsOrQ+gU8M85np+RcQZG\
# RORkpz5THheh7x737oyMMzAiIivpvZ+V3Sv5e4ZOhWdqHsMZGBGRVfTez6pfBYROantvtZmai3EG\
# RkRkFbX7WWqzp92LgPZWbe+de2F6tUmIAUZEZBW1WZLe8ViZucCopanVJDEGGBGRVdRmSXrHc3oD\
# uQMB+MJ/jg14roED4D0wIiLrjFra9R4YkHj2pPb80cs9GVixOAMjIrJK0ezwbEnr7Env8z2GMzAi\
# IisVzdYXQHqf7yGcgRERkZQYYEREJCVpLiEWFhaiR48eyMzMRFZWFurq6uwuiYjIGepXhdeMnfos\
# 3Lk4aqknLjtKE2AA8Oabb6JPnz52l0FE5Bwe3q2elxCJiNTIcA6X3t09XESaAPP5fLjqqqswevRo\
# BAIBu8shIrfrmNmcOgBAdM5srAgxPcGZ7i4eEpPmEuL27duRn5+PY8eOoaKiAhdddBEmTJjQ5TmB\
# QCASbo2NjXaUSURukWhmY+alOb2XBHMv/C5kFcZdTpoZWH5+PgAgLy8PM2bMQG1tbdxzqqqqUFdX\
# h7q6OvTt29fqEonITeya2ei9JDhqaXh3jmge2RtRigD79ttvcfLkych/v/HGGygtLbW5KiJytUT7\
# E5p5b0xvcHp4tw4pLiF+8cUXmDFjBgCgra0Nt9xyC6ZMmWJzVUTkamr7EOZPM7frL5VLgh7drUOK\
# ACsuLsbu3bvtLoOI3ExpLdXYQPyY2ffG9G7462FSBBgRkanUGifGBoAfNnR97o5bld/DqHtjHSHo\
# wYXJejHAiIj0zKqs6Prz6CVBvaRo4iAiMpWexgkPd/05DQOMiEjPicgdXX85vTvHMr7X9Tky7ODh\
# AryESESkp3GifhXw7gKgtalzLNjU2YkIeHZvQqsxwIiItDZOxDZ7RItebGzHDh4exAAjIgK0NU4o\
# NXtES9SJ6IG9Ca3Ge2BE5D2p3qNKFkK5F+q7n0Zp4QyMiLwlnfOz1Froga73zLgQ2RKcgRGRnFKd\
# RaVzfpZSCz0AZPfu3H/Qw3sTWo0BRkTySeesLtU1XweSh6FSC312b8C/vGtAFc0O7+BxS3vnTh5s\
# qzccA4yI5JPOLCrhvSiNYRg63fnfHS30as+382BMl2OAEZF80jmrS+0yYLToMIxcqvQBa7KAHT/S\
# F57phC0lxAAjIvmk0+kXe49KzanPYmZPAEQo8fONGCfNGGBEJJ909yOMvkeVO1D

# %% [markdown]
# In practice, we don't calculate on the whole file at once, but we use *mini-batches*.

# %% [markdown]
# ## Vocab

# %% [markdown]
# - Learning rate
# - Epoch
# - Minibatch
# - SGD
# - Model / Architecture
# - Parameters
# - Loss function
#
# For classification problems, we use *cross entropy loss*, also known as *negative log likelihood loss*. This penalizes incorrect confident predictions, and correct unconfident predictions.
